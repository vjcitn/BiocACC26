# %% [markdown]
# # BiocACC26: remarks on Bioc/AnVIL symbiosis
#
# Vincent J. Carey, stvjc at channing.harvard.edu
# 2026-08-29
#
# # Introduction

# %%
library(AnVIL)
# Out:
# 3/26 packages newly attached/loaded, see sessionInfo() for details.
#  [1] "add_libpaths"        "anvil_set_auth_json" "avtable_gadget"
#  [4] "avworkflow_gadget"   "avworkspace_gadget"  "browse_workspace"
#  [7] "Dockstore"           "empty_object"        "Leonardo"
# [10] "operations"          "Rawls"               "schemas"
# [13] "Service"             "show"                "tags"
# [16] "TDR"                 "Terra"
